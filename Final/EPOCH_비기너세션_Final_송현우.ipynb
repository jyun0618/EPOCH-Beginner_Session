# %% [markdown]
# # **🌱 EPOCH 비기너 세션 Final Test 🔥**

# %% [markdown]
# ---

# %% [markdown]
# ## **1️⃣ 'Sleep_health_and_lifestyle_dataset.csv' 파일을 불러와 수면 데이터를 분석하세요.**

# %% [markdown]
# ### (0) 데이터를 불러오세요.

# %%
import pandas as pd
data = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
df = pd.DataFrame(data)
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %% [markdown]
# ### (1) 성별에 따른 평균 수면 시간('Sleep Duration')을 출력하세요.

# %%
df.groupby("Gender")['Sleep Duration'].mean()
# Out:
# Gender
# Female    7.229730
# Male      7.036508
# Name: Sleep Duration, dtype: float64

# %% [markdown]
# ### (2) 스트레스 수준('Stress Level')이 3 이상인 사람들의 수면 질('Quality of Sleep') 평균을 구하세요.

# %%
df[df['Stress Level'] >= 3]["Quality of Sleep"].mean()
# Out:
# np.float64(7.31283422459893)

# %% [markdown]
# ### (3) 아래와 같은 수면 데이터에 대한 네 가지 그래프를 그리세요.
# * colors = ['gold', 'gray','darkgray', 'silver', 'lightgray', 'whitesmoke'] & 'coral' & 'purple' & 'green'
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sleep_counts = df["Quality of Sleep"].value_counts()
plt.pie(
    sleep_counts,
    labels=sleep_counts.index,
    autopct="%1.1f%%",
    startangle=90,
    counterclock=False,
    colors=['gold', 'gray', 'darkgray', 'silver', 'lightgray', 'whitesmoke']
)
plt.title("Distribution of Quality of Sleep")

plt.subplot(2, 2, 2)
y = df.groupby('Age')['Sleep Duration'].mean()
plt.bar(y.index, y.values, color='coral')
plt.grid(True, axis='y', color='lightblue')
plt.xlabel('Age')
plt.ylabel('Sleep Duration (Hours)')
plt.title('Average Sleep Duration by Age')

plt.subplot(2, 2, 3)
a = df.groupby('Quality of Sleep').count()
plt.bar(a.index, a['Person ID'], color='purple')
plt.xlabel('Quality of Sleep')
plt.ylabel('Count')
plt.title('Counts of Quality of Sleep Rating')

plt.subplot(2, 2, 4)
b = df.groupby('Age')['Quality of Sleep'].mean()
plt.plot(b.index, b.values, marker='o', color='green')
plt.xlabel('Age')
plt.ylabel('Quality of Sleep')
plt.title('Quality of Sleep Trend by Age')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

sleep_counts = df["Quality of Sleep"].value_counts()

plt.pie(sleep_counts, labels=sleep_counts.index, autopct="%1.1f%%", startangle=90, counterclock=False, colors = ['gold', 'gray','darkgray', 'silver', 'lightgray', 'whitesmoke'] )
plt.title("Distribution of Quality of Sleep")
plt.show()

# %%
y = df.groupby('Age')['Sleep Duration'].mean()
plt.bar(y.index, y.values, color='coral')
plt.grid(True,axis='y', color='lightblue')
plt.xlabel('Age')
plt.ylabel('Sleep Duration  (Hours)')
plt.title('Average Sleep Duration by Age')
# Out:
# Text(0.5, 1.0, 'Average Sleep Duration by Age')

# %%
a = df.groupby('Quality of Sleep').count()
plt.bar(a.index, a['Person ID'], color='purple')
plt.xlabel('Quality of Sleep')
plt.ylabel('Count')
plt.title('Counts of Quality of Sleep Rating')
# Out:
# Text(0.5, 1.0, 'Counts of Quality of Sleep Rating')

# %%
b = df.groupby('Age')['Quality of Sleep'].mean()
plt.plot(b.index, b.values, marker='o', color='green')
plt.xlabel('Age')
plt.ylabel('Quality of Sleep')
plt.title('Quality of Sleep Trend by age')
# Out:
# Text(0.5, 1.0, 'Quality of Sleep Trend by age')

# %% [markdown]
# ## **2️⃣‘calendar.csv' 파일과 'listings.csv' 파일을 불러와 Airbnb 예약 데이터를 분석하세요.**

# %% [markdown]
# ### (0) 데이터를 불러오세요.

# %%
data1 = pd.read_csv('calendar.csv')
data2 = pd.read_csv('listings.csv')
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
# print(df1.head(5))
# print(df2.head(5))
print(df1.columns)
print(df2.columns)
# Out:
# Index(['listing_id', 'date', 'available', 'price', 'adjusted_price',
#        'minimum_nights', 'maximum_nights'],
#       dtype='object')
# Index(['listing_id', 'name', 'host_id', 'host_name', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license', 'Unnamed: 12'],
#       dtype='object')

# %% [markdown]
# ### (1) 두 데이터셋을 'listing_id'를 기준으로 병합하여 숙소가 예약이 가능한 상태인 날짜의 수를 세어 숙소별로 출력하세요.
# * Hint: 'availability_365'가 0보다 크면 예약 가능한 상태

# %%
merged = pd.merge(df1, df2, on='listing_id')
merged[merged['available'] == 't'].groupby('listing_id')['listing_id'].count()
# Out:
# listing_id
# 6606        147
# 9419        337
# 9531        133
# 9534          1
# 9596         16
#            ...
# 54385010    102
# 54396923     77
# 54396956     65
# 54397152     37
# 54397466    132
# Name: listing_id, Length: 2866, dtype: int64

# %%
df = pd.merge(df1, df2, on='listing_id')

available_count = df[df['availability_365'] > 0].groupby('listing_id')['date'].count()

available_count.columns = ['listing_id', 'available_days_count']
print(available_count)
# Out:
# listing_id
# 6606        365
# 9419        365
# 9531        365
# 9534        365
# 9596        365
#            ...
# 54385010    365
# 54396923    365
# 54396956    365
# 54397152    365
# 54397466    365
# Name: date, Length: 2860, dtype: int64
