# %% [markdown]
# **4.8~**

# %% [markdown]
# ### 4.8 칼럼 추가하기

# %%
from pandas import DataFrame, Series

data=[
    ["3R",1510,7.36],
    ["3SOFT",1790,1.65],
    ["ACTS",1185,1.28]
]

index=["037730","036360","005760"]
columns=["종목명","현재가","등락률"]

df=DataFrame(data=data,index=index,columns=columns)
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
s=Series(data=[1600,1600,1600],index=df.index)
df['목표가']=s
print(df)
# Out:
#           종목명   현재가   등락률   목표가
# 037730     3R  1510  7.36  1600
# 036360  3SOFT  1790  1.65  1600
# 005760   ACTS  1185  1.28  1600

# %%
df['목표가']=1600 #위와 같은 결과를 얻을 수 있음
print(df)
# Out:
#           종목명   현재가   등락률   목표가
# 037730     3R  1510  7.36  1600
# 036360  3SOFT  1790  1.65  1600
# 005760   ACTS  1185  1.28  1600

# %%
#기존 시리즈 간의 연산을 통해 커럼 추가
df["괴리율"]=(df["목표가"]-df["현재가"])/df['현재가']
#따옴표 홑/쌍 상관없다는 의미에서 두 가지 다 사용?
print(df)
# Out:
#           종목명   현재가   등락률   목표가       괴리율
# 037730     3R  1510  7.36  1600  0.059603
# 036360  3SOFT  1790  1.65  1600 -0.106145
# 005760   ACTS  1185  1.28  1600  0.350211

# %% [markdown]
# ### 4.9 로우 추가하기

# %%
data=[
    ["3R",1510,7.36],
    ["3SOFT",1790,1.65],
    ["ACTS",1185,1.28]
]

index=["037730","036360","005760"]
columns=["종목명","현재가","등락률"]

df=DataFrame(data=data,index=index,columns=columns)
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
s=Series(data=["LG전자",60000,3.84],index=df.columns)
df.loc["066570"]=s
print(df)
# Out:
#           종목명    현재가   등락률
# 037730     3R   1510  7.36
# 036360  3SOFT   1790  1.65
# 005760   ACTS   1185  1.28
# 066570   LG전자  60000  3.84

# %%
data=[
    ["3R",1510,7.36],
    ["3SOFT",1790,1.65],
    ["ACTS",1185,1.28]
]

index=["037730","036360","005760"]
columns=["종목명","현재가","등락률"]

df=DataFrame(data=data,index=index,columns=columns)
df

df.loc["066570"]=['LG전자',60000,3.84] #위와 같은 결과를 출력하는 다른 방식!
print(df)
# Out:
#           종목명    현재가   등락률
# 037730     3R   1510  7.36
# 036360  3SOFT   1790  1.65
# 005760   ACTS   1185  1.28
# 066570   LG전자  60000  3.84

# %%
#append사용 > x 버전차이?
#s=Series(data=["LG전자",60000,3.84],index=df.columns, name="066570")
#new_df=df.append(s)
#print(new_df)

# %%
# append 대신 pd.concat 사용
data=[
    ["3R",1510,7.36],
    ["3SOFT",1790,1.65],
    ["ACTS",1185,1.28]
]

index=["037730","036360","005760"]
columns=["종목명","현재가","등락률"]

df=DataFrame(data=data,index=index,columns=columns)
df

s=Series(data=["LG전자",60000,3.84],index=df.columns, name="066570")
new_df = pd.concat([df, s.to_frame().T]) # Series를 DataFrame으로 변환하고 전치하여 concat에 전달
print(new_df)
# Out:
#           종목명    현재가   등락률
# 037730     3R   1510  7.36
# 036360  3SOFT   1790  1.65
# 005760   ACTS   1185  1.28
# 066570   LG전자  60000  3.84

# %% [markdown]
# ### 4.10 칼럼/로우 삭제하기

# %%
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
#컬럼 삭제
df_new=df.drop("현재가",axis=1) #axis=0: 행 방향, axis=1: 열방향
print(df)
print(df_new)
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28
#           종목명   등락률
# 037730     3R  7.36
# 036360  3SOFT  1.65
# 005760   ACTS  1.28

# %%
#로우 삭제
df_new=df.drop("037730",axis=0) #원본데이터프레임을 변경하려면 axis=0 뒤에 inplace=True.
print(df)
print(df_new)
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28
#           종목명   현재가   등락률
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
#한 번에 여러 개의 로우나 컬럼 삭제 -> 리스트 형태로 인덱스나 컬럼의 레이블 넘겨줌.
df.drop(["037730","005760"],axis=0)
# Out:
#           종목명   현재가   등락률
# 036360  3SOFT  1790  1.65

# %% [markdown]
# ### 4.11 컬럼 레이블 변경

# %% [markdown]
# 컬럼 레이블과 인덱스의 이름을 수정하는 방법

# %%
df
# Out:
#           종목명   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %%
from pandas import DataFrame
data=[
    ["3R",1510,7.36],
    ["3SOFT",1790,1.65],
    ["ACTS",1185,1.28]
]
index=["037730","036360","005760"]
columns=["종목명","현재가","등락률"]

df=DataFrame(data=data,index=index,columns=columns)
df.rename(columns={'종목명':'code'}, inplace=True) #중괄호!!
print(df)
# Out:
#          code   현재가   등락률
# 037730     3R  1510  7.36
# 036360  3SOFT  1790  1.65
# 005760   ACTS  1185  1.28

# %% [markdown]
# ### 4.12 데이터 타입 변경

# %%
data = [
    ["1,000","1,100","1,510"],
    ["1,410","1,420","1,790"],
    ["850","900","1,185"],#쉼표?
]

columns=["03/02","03/03","03/04"]
df=DataFrame(data=data,columns=columns)
df
# Out:
#    03/02  03/03  03/04
# 0  1,000  1,100  1,510
# 1  1,410  1,420  1,790
# 2    850    900  1,185

# %%
#쉼표 없어도 같게 출력..

data = [
    ["1,000","1,100","1,510"],
    ["1,410","1,420","1,790"],
    ["850","900","1,185"]
]

columns=["03/02","03/03","03/04"]
df=DataFrame(data=data,columns=columns)
df
# Out:
#    03/02  03/03  03/04
# 0  1,000  1,100  1,510
# 1  1,410  1,420  1,790
# 2    850    900  1,185

# %%
#map적용
def remove_comma(x):
  return int(x.replace(',',''))

df['03/02']=df['03/02'].map(remove_comma)
df['03/03']=df['03/03'].map(remove_comma)
df['03/04']=df['03/04'].map(remove_comma)
print(df)
# Out:
#    03/02  03/03  03/04
# 0   1000   1100   1510
# 1   1410   1420   1790
# 2    850    900   1185

# %% [markdown]
# 반복되는 코드로 가독성 떨어짐.

# %%
data = [
    ["1,000","1,100","1,510"],
    ["1,410","1,420","1,790"],
    ["850","900","1,185"]
]

columns=["03/02","03/03","03/04"]
df=DataFrame(data=data,columns=columns)

def remove_comma(x):
  return int(x.replace(',',''))

df=df.applymap(remove_comma) #applymap!!
#print(df)
print(df.dtypes)
# Out:
# 03/02    int64
# 03/03    int64
# 03/04    int64
# dtype: object
# /tmp/ipython-input-3070597867.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df=df.applymap(remove_comma)

# %%
#데이터타입 변경가능한 astype매서드 사용
import numpy as np
from pandas import DataFrame

def remove_comma(x):
  return int(x.replace(',',''))

data = [
    ["1,000","1,100","1,510"],
    ["1,410","1,420","1,790"],
    ["850","900","1,185"]
]

columns=["03/02","03/03","03/04"]
df=DataFrame(data=data,columns=columns)

df=df.applymap(remove_comma)
df=df.astype({"03/02":np.int64,"03/03":np.int64,"03/04":np.int64})
print(df.dtypes)
# Out:
# 03/02    int64
# 03/03    int64
# 03/04    int64
# dtype: object
# /tmp/ipython-input-921790217.py:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df=df.applymap(remove_comma)

# %% [markdown]
# ### 4.13 컬럼의 문자열 다루기

# %%
from pandas import DataFrame
import numpy as np

data=[
    {"cd":"A060310","nm":"3S","close":"2,920"},
    {"cd":"A065570","nm":"AJ네트웍스","close":"6,250"},
    {"cd":"A006840","nm":"AK홀딩스","close":"29,700"},
    {"cd":"A054620","nm":"APS홀딩스","close":"19,400"}
]

df=DataFrame(data=data)
df
# Out:
#         cd      nm   close
# 0  A060310      3S   2,920
# 1  A065570  AJ네트웍스   6,250
# 2  A006840   AK홀딩스  29,700
# 3  A054620  APS홀딩스  19,400

# %%
#cd컬럼의 A제거하기
df['cd']=df['cd'].str[1:]
df['close']=df['close'].str.replace(',','').astype(np.int64) #쉼표 제거
df
# Out:
#        cd      nm  close
# 0  060310      3S   2920
# 1  065570  AJ네트웍스   6250
# 2  006840   AK홀딩스  29700
# 3  054620  APS홀딩스  19400
